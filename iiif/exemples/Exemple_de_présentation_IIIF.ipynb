# %% [markdown]
# ## Introduction
#
# Exemple de présentation en ligne avec un **Jupyter Notebook**, combinant du texte Markdown, avec du code Python et intégrant un _viewer_ IIIF embarqué dans un `<iframe>` (voir le [GitHub](https://github.com/iramat) de l'IRAMAT).

# %%
# @title IIIF céramique

from IPython.display import IFrame, display, HTML
IFrame('https://iramat-apps.cnrs.fr/view/creuset.html', width=1200, height=800)
# Out:
#         <iframe
#             width="1200"
#             height="800"
#             src="https://iramat-apps.cnrs.fr/view/creuset.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title IIIF numismatique

from IPython.display import IFrame, display, HTML
IFrame('https://iramat-apps.cnrs.fr/view/iramat_bnf_iiif.html', width=1200, height=800)
# Out:
#         <iframe
#             width="1200"
#             height="800"
#             src="https://iramat-apps.cnrs.fr/view/iramat_bnf_iiif.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
